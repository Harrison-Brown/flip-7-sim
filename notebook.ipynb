# %%
import random 
deck = [0] + [
    i for i in range(1, 13) for x in range(i) 
]
random.shuffle(deck)
print(deck)
# Out:
# [5, 7, 10, 11, 4, 12, 12, 6, 8, 3, 7, 5, 6, 8, 5, 11, 10, 9, 12, 10, 12, 10, 12, 9, 10, 11, 3, 11, 9, 6, 9, 9, 8, 12, 5, 11, 11, 10, 11, 9, 9, 10, 12, 2, 4, 8, 0, 1, 11, 10, 6, 12, 8, 11, 12, 4, 7, 9, 9, 7, 4, 8, 7, 7, 2, 11, 10, 5, 6, 8, 12, 12, 7, 12, 8, 3, 11, 10, 6]

# %%
class
